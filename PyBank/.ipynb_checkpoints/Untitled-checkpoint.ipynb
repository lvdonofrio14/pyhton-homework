# %% [markdown]
# # Step 1

# %%
import pandas as pd
import numpy as np

bank = pd.read_csv("02-Python_Assignment_PyBank_Resources_budget_data.csv")
bank.head()

print("Financial Analysis")
print("-" *25)
num_rows = 0
for rows in bank.values:
    num_rows += 1
print(f'Total Months: {num_rows}')
# Out:
# Financial Analysis
# -------------------------
# Total Months: 86

# %%
banks.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-6605966994ca> in <module>
# ----> 1 banks.count()
#
# NameError: name 'banks' is not defined

# %% [markdown]
# # Step 2

# %%
net_total = bank.iloc[0:,1]
print (f'Total: ${net_total.sum()}')
# Out:
# Total: $38382578

# %%
net_total = 0
for i,j in bank.values:
    net_total + j
print(net_total)
# Out:
# 0

# %%
total = bank.groupby["Profit/Losses"].sum()
print('total')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-59892801c915> in <module>
# ----> 1 total = bank.groupby["Profit/Losses"].sum()
#       2 print('total')
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# # Step 3

# %%
periods = bank['Profit/Losses'].count() - 1
change = bank["Profit/Losses"] - bank["Profit/Losses"].shift(1)
average_change = (change.sum()/ periods).round(2)
print(f'Average Change: ${average_change}')
# Out:
# Average Change: $-2315.12

# %% [markdown]
# # Step 4

# %%
bank['Profit/Losses'].max()
# Out:
# 1170593

# %%
bank["Profit/Losses"].min()
# Out:
# -1196225

# %%
max_change = change.max()
print(max_change)
# Out:
# 1926159.0

# %%
min_change = change.min()
print(min_change)
# Out:
# -2196167.0

# %%
bank["Change"] = change

# %%
bank.head()
# Out:
#        Date  Profit/Losses    Change
# 0  Jan-2010         867884       NaN
# 1  Feb-2010         984655  116771.0
# 2  Mar-2010         322013 -662642.0
# 3  Apr-2010         -69417 -391430.0
# 4  May-2010         310503  379920.0

# %%
bank[bank.Change== max_change]["Date"]
# Out:
# 25    Feb-2012
# Name: Date, dtype: object

# %%
bank[bank.Change== min_change]["Date"]
# Out:
# 44    Sep-2013
# Name: Date, dtype: object
